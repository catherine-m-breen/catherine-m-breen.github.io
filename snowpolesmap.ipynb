# %% [markdown]
# # Time-Lapse Camera Maps
#
# Currently there are 13 different networks with over 500,000 timelapse camera images. Please reach out if you'd like to include your camera network on this map.

# %%
import json # package to read the json 
import folium # package for interactive map
import branca # package for html formatting in folium 
from branca.element import Figure, MacroElement, Template # package for additional html viz

# %%
dictionary = '/Users/catherinebreen/code/catherine-m-breen.github.io/snowpoles_dict.json'

with open(dictionary, "r") as f:
    snowpole_data = json.load(f)

# %%
m = folium.Map(location=(45, -96), zoom_start=3)


welcome_html = """
<div style="
    position: fixed;
    bottom: 50px;
    left: 50px;
    width: 300px;
    z-index: 9999;
    background-color: white;
    padding: 10px;
    border: 2px solid grey;
    box-shadow: 3px 3px 10px rgba(0,0,0,0.3);
">
    <h4>Welcome to the Snowpole Network Map</h4>
    <p>This map shows various snowpole observation sites from NASA and university partners.</p>
    <p>Click on any marker to learn more about the site.</p>
</div>
"""
m.get_root().html.add_child(folium.Element(welcome_html))

for key in snowpole_data.keys():
    html = f"""
    <div style="display: flex; flex-direction: row; width: 100%;">
        <div style="flex: 1; padding-right: 20px; max-width: 50%;">
            <h1>{snowpole_data[key].get('owner', 'N/A')}</h1>
            <p><strong>Contact:</strong> {snowpole_data[key].get('contact', 'N/A')}</p>
            <p><strong>Year:</strong> {snowpole_data[key].get('year(s)', 'N/A')}</p>
            <p><strong>Sites:</strong> {snowpole_data[key].get('sites', 'N/A')}</p>
            <p><strong>Labeled:</strong> {snowpole_data[key].get('labeled', 'N/A')}</p>
            <p><strong>Data availability:</strong> {snowpole_data[key].get('data availability', 'N/A')}</p>
        </div>
        <div style="flex: 1; display: flex; align-items: center; justify-content: center;">
            <img src="{snowpole_data[key]['ex_img_path']}" width="200" style="max-width: 100%; height: auto;">
        </div>
    </div>
    """

    iframe = branca.element.IFrame(html=html, width=500, height=300)
    popup = folium.Popup(iframe, max_width=500)
    # folium.Marker(
    #     location=snowpole_data[key]['location'],
    #     tooltip="Click me!",
    #    # popup=f"owner: {snowpole_data[key]['owner']}",
    #     popup = popup,
    #     icon=folium.Icon(icon="camera"), 
    # ).add_to(m)

    marker = folium.Marker(
        location=snowpole_data[key]['location'],
        tooltip="Click me!",
        popup=popup,
        icon=folium.Icon(icon="camera"),
    )
    
    # Add JS that zooms and pans to marker
    zoom_js = f"""
    function(e){{
        var latlng = e.target.getLatLng();
        e.target._map.setView(latlng, 10);  // 5 = zoom level
    }}
    """
    marker.add_child(folium.Element(
        f"<script>var m = this; m.on('click', {zoom_js});</script>"
    ))

    marker.add_to(m)

# %%
## could add NEON sites; there are probs sites in CA too? 
## Bongio study: https://zenodo.org/records/3724877

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6d7a534c0ee9be710222999d06f657c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 50px;
#     left: 50px;
#     width: 300px;
#     z-index: 9999;
#     background-color: white;
#     padding: 10px;
#     border: 2px solid grey;
#     box-shadow: 3px 3px 10px rgba(0,0,0,0.3);
# &quot;&gt;
#     &lt;h4&gt;Welcome to the Snowpole Network Map&lt;/h4&gt;
#     &lt;p&gt;This map shows various snowpole observation sites from NASA and university partners.&lt;/p&gt;
#     &lt;p&gt;Click on any marker to learn more about the site.&lt;/p&gt;
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6d7a534c0ee9be710222999d06f657c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d6d7a534c0ee9be710222999d06f657c = L.map(
#                 &quot;map_d6d7a534c0ee9be710222999d06f657c&quot;,
#                 {
#                     center: [45.0, -96.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2652e129cf276ed5b7f7a27502426170 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2652e129cf276ed5b7f7a27502426170.addTo(map_d6d7a534c0ee9be710222999d06f657c);
#
#
#             var marker_1387df7d36cf2833b746856fd28be30a = L.marker(
#                 [38.0, -108.0],
#                 {}
#             ).addTo(map_d6d7a534c0ee9be710222999d06f657c);
#
#
#             var icon_07289cf1fed4f42b6d8b2d15aa6c8b86 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1387df7d36cf2833b746856fd28be30a.setIcon(icon_07289cf1fed4f42b6d8b2d15aa6c8b86);
#
#
#         var popup_3e0bb473088df169f9c4bd62620ff124 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var i_frame_9485ff805a6da59d71b820fc2b8ca556 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;500&quot; style=&quot;border:none !important;&quot; height=&quot;300&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_3e0bb473088df169f9c4bd62620ff124.setContent(i_frame_9485ff805a6da59d71b820fc2b8ca556);
#
#
#
#         marker_1387df7d36cf2833b746856fd28be30a.bindPopup(popup_3e0bb473088df169f9c4bd62620ff124)
#         ;
#
#
#
#
#             marker_1387df7d36cf2833b746856fd28be30a.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_225f6f08f0c9c5ae2ce90e7da0fa178e = L.marker(
#                 [39.03, -108.0],
#                 {}
#             ).addTo(map_d6d7a534c0ee9be710222999d06f657c);
#
#
#             var icon_125ead161d155321117b62e22ba63564 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_225f6f08f0c9c5ae2ce90e7da0fa178e.setIcon(icon_125ead161d155321117b62e22ba63564);
#
#
#         var popup_df759a3233e04d0783b5a80c9bac8830 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var i_frame_c59e171d92030fb619aaf23ba698cc19 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;500&quot; style=&quot;border:none !important;&quot; height=&quot;300&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_df759a3233e04d0783b5a80c9bac8830.setContent(i_frame_c59e171d92030fb619aaf23ba698cc19);
#
#
#
#         marker_225f6f08f0c9c5ae2ce90e7da0fa178e.bindPopup(popup_df759a3233e04d0783b5a80c9bac8830)
#         ;
#
#
#
#
#             marker_225f6f08f0c9c5ae2ce90e7da0fa178e.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fd240e4fcaadf1d5a2375a1e60618cff = L.marker(
#                 [64.0, -147.0],
#                 {}
#             ).addTo(map_d6d7a534c0ee9be710222999d06f657c);
#
#
#             var icon_aea5f7ee6a5e86ea4797fa1abb04dfb5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fd240e4fcaadf1d5a2375a1e60618cff.setIcon(icon_aea5f7ee6a5e86ea4797fa1abb04dfb5);
#
#
#         var popup_f47f7267734ec333ceebda316cde7ec9

# %%
## when clicked on 
# number of poles 
# data source owner
# contact information
